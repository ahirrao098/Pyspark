# %%
# !pip install pyspark
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 281.3 MB 50 kB/s
# ...
#      |████████████████████████████████| 199 kB 54.0 MB/s
# ...
#   Created wheel for pyspark: filename=pyspark-3.3.0-py2.py3-none-any.whl size=281764026 sha256=dfba8703ecafaa743a58a294061a45abc7bdee20ad7e33730ae3f51d23274780
#   Stored in directory: /root/.cache/pip/wheels/7a/8e/1b/f73a52650d2e5f337708d9f6a1750d451a7349a867f928b885
# Successfully built pyspark
# ...

# %%
from pyspark.sql import SparkSession

# %%
spark = SparkSession.builder\
    .master("local[1]")\
    .appName("SparkByExamples.com")\
    .getOrCreate()

# %%
dataList = [("Java", 20000), ("Python", 100000), ("Scala", 3000)]

# %%
rdd=spark.sparkContext.parallelize(dataList)#rdd=resilliance distribution dataset
rdd
# Out:
# ParallelCollectionRDD[1] at readRDDFromFile at PythonRDD.scala:274

# %%
rdd.count()
# Out:
# 3

# %%
rdd.collect()
# Out:
# [('Java', 20000), ('Python', 100000), ('Scala', 3000)]

# %%
rdd.first()
# Out:
# ('Java', 20000)

# %%
rdd.max()
# Out:
# ('Scala', 3000)

# %%
data = [('James','','Smith','1991-04-01','M',3000),
  ('Michael','Rose','','2000-05-19','M',4000),
  ('Robert','','Williams','1978-09-05','M',4000),
  ('Maria','Anne','Jones','1967-12-01','F',4000),
  ('Jen','Mary','Brown','1980-02-17','F',-1)
]

# %%
columns = ["firstname","middlename","lastname","dob","gender","salary"]
df = spark.createDataFrame(data=data, schema = columns)

# %%
df.show()
# Out:
# +---------+----------+--------+----------+------+------+
# |firstname|middlename|lastname|       dob|gender|salary|
# +---------+----------+--------+----------+------+------+
# |    James|          |   Smith|1991-04-01|     M|  3000|
# |  Michael|      Rose|        |2000-05-19|     M|  4000|
# |   Robert|          |Williams|1978-09-05|     M|  4000|
# |    Maria|      Anne|   Jones|1967-12-01|     F|  4000|
# |      Jen|      Mary|   Brown|1980-02-17|     F|    -1|
# +---------+----------+--------+----------+------+------+

# %%
columns = ["language","users_count"]
data = [("Java", "20000"), ("Python", "100000"), ("Scala", "3000")]

# %%
rdd = spark.sparkContext.parallelize(data)

# %%
dfFromRDD1 = rdd.toDF()
dfFromRDD1.printSchema()
# Out:
# root
#  |-- _1: string (nullable = true)
#  |-- _2: string (nullable = true)

# %%
dfFromRDD1 = rdd.toDF(columns)#rdd to data frame
dfFromRDD1.printSchema()
# Out:
# root
#  |-- language: string (nullable = true)
#  |-- users_count: string (nullable = true)

# %%
dfFromRDD1.show()
# Out:
# +--------+-----------+
# |language|users_count|
# +--------+-----------+
# |    Java|      20000|
# |  Python|     100000|
# |   Scala|       3000|
# +--------+-----------+

# %%
from pyspark.sql.types import StructType,StructField, StringType, IntegerType
data2 = [("James","","Smith","36636","M",3000),
    ("Michael","Rose","","40288","M",4000),
    ("Robert","","Williams","42114","M",4000),
    ("Maria","Anne","Jones","39192","F",4000),
    ("Jen","Mary","Brown","","F",-1)
  ]

schema = StructType([ \
    StructField("firstname",StringType(),True), \
    StructField("middlename",StringType(),True), \
    StructField("lastname",StringType(),True), \
    StructField("id", StringType(), True), \
    StructField("gender", StringType(), True), \
    StructField("salary", IntegerType(), True) \
  ])
 
df = spark.createDataFrame(data=data2,schema=schema)
df.printSchema()
df.show(truncate=False)
# Out:
# root
#  |-- firstname: string (nullable = true)
#  |-- middlename: string (nullable = true)
#  |-- lastname: string (nullable = true)
#  |-- id: string (nullable = true)
#  |-- gender: string (nullable = true)
#  |-- salary: integer (nullable = true)
#
# +---------+----------+--------+-----+------+------+
# |firstname|middlename|lastname|id   |gender|salary|
# +---------+----------+--------+-----+------+------+
# |James    |          |Smith   |36636|M     |3000  |
# |Michael  |Rose      |        |40288|M     |4000  |
# |Robert   |          |Williams|42114|M     |4000  |
# |Maria    |Anne      |Jones   |39192|F     |4000  |
# |Jen      |Mary      |Brown   |     |F     |-1    |
# +---------+----------+--------+-----+------+------+

# %%
pandasDF = df.toPandas()#converting dataframe to pandas data frame

# %%
pandasDF
# Out:
#   firstname middlename  lastname     id gender  salary
# 0     James                Smith  36636      M    3000
# 1   Michael       Rose            40288      M    4000
# 2    Robert             Williams  42114      M    4000
# 3     Maria       Anne     Jones  39192      F    4000
# 4       Jen       Mary     Brown             F      -1

# %%
pandasDF.shape
# Out:
# (5, 6)

# %%
df.show(truncate=False)#whole data set showing
# Out:
# +---------+----------+--------+-----+------+------+
# |firstname|middlename|lastname|id   |gender|salary|
# +---------+----------+--------+-----+------+------+
# |James    |          |Smith   |36636|M     |3000  |
# |Michael  |Rose      |        |40288|M     |4000  |
# |Robert   |          |Williams|42114|M     |4000  |
# |Maria    |Anne      |Jones   |39192|F     |4000  |
# |Jen      |Mary      |Brown   |     |F     |-1    |
# +---------+----------+--------+-----+------+------+

# %%
df.show(2,truncate=False) #top to records showing
# Out:
# +---------+----------+--------+-----+------+------+
# |firstname|middlename|lastname|id   |gender|salary|
# +---------+----------+--------+-----+------+------+
# |James    |          |Smith   |36636|M     |3000  |
# |Michael  |Rose      |        |40288|M     |4000  |
# +---------+----------+--------+-----+------+------+
# only showing top 2 rows

# %%
# Display 2 rows & column values 3 characters
df.show(2,truncate=3) #it is only showing 3 character in each column remaining it is removing
# Out:
# +---------+----------+--------+---+------+------+
# |firstname|middlename|lastname| id|gender|salary|
# +---------+----------+--------+---+------+------+
# |      Jam|          |     Smi|366|     M|   300|
# |      Mic|       Ros|        |402|     M|   400|
# +---------+----------+--------+---+------+------+
# only showing top 2 rows

# %%
columns = ["Seqno","Quote"]
data = [("1", "Be the change that you wish to see in the world"),
    ("2", "Everyone thinks of changing the world, but no one thinks of changing himself."),
    ("3", "The purpose of our lives is to be happy."),
    ("4", "Be cool.")]
df = spark.createDataFrame(data,columns)
df.show()
# Out:
# +-----+--------------------+
# |Seqno|               Quote|
# +-----+--------------------+
# |    1|Be the change tha...|
# |    2|Everyone thinks o...|
# |    3|The purpose of ou...|
# |    4|            Be cool.|
# +-----+--------------------+

# %%
df.show(truncate=False)
# Out:
# +-----+-----------------------------------------------------------------------------+
# |Seqno|Quote                                                                        |
# +-----+-----------------------------------------------------------------------------+
# |1    |Be the change that you wish to see in the world                              |
# |2    |Everyone thinks of changing the world, but no one thinks of changing himself.|
# |3    |The purpose of our lives is to be happy.                                     |
# |4    |Be cool.                                                                     |
# +-----+-----------------------------------------------------------------------------+

# %%
df.show(truncate=25)#truncate is only work on string data not on integer
# Out:
# +-----+-------------------------+
# |Seqno|                    Quote|
# +-----+-------------------------+
# |    1|Be the change that you...|
# |    2|Everyone thinks of cha...|
# |    3|The purpose of our liv...|
# |    4|                 Be cool.|
# +-----+-------------------------+

# %%
df.show(n=3,truncate=25,vertical=True)#it is showing verical data
# Out:
# -RECORD 0--------------------------
#  Seqno | 1
#  Quote | Be the change that you...
# -RECORD 1--------------------------
#  Seqno | 2
#  Quote | Everyone thinks of cha...
# -RECORD 2--------------------------
#  Seqno | 3
#  Quote | The purpose of our liv...
# only showing top 3 rows

# %%
structureData = [
    (("James","","Smith"),"36636","M",3100),
    (("Michael","Rose",""),"40288","M",4300),
    (("Robert","","Williams"),"42114","M",1400),
    (("Maria","Anne","Jones"),"39192","F",5500),
    (("Jen","Mary","Brown"),"","F",-1)
  ]
structureSchema = StructType([
        StructField('name', StructType([
             StructField('firstname', StringType(), True),
             StructField('middlename', StringType(), True),
             StructField('lastname', StringType(), True)
             ])),
         StructField('id', StringType(), True),
         StructField('gender', StringType(), True),
         StructField('salary', IntegerType(), True)
         ])

df2 = spark.createDataFrame(data=structureData,schema=structureSchema)
df2.printSchema()
df2.show(truncate=False)
# Out:
# root
#  |-- name: struct (nullable = true)
#  |    |-- firstname: string (nullable = true)
#  |    |-- middlename: string (nullable = true)
#  |    |-- lastname: string (nullable = true)
#  |-- id: string (nullable = true)
#  |-- gender: string (nullable = true)
#  |-- salary: integer (nullable = true)
#
# +--------------------+-----+------+------+
# |name                |id   |gender|salary|
# +--------------------+-----+------+------+
# |{James, , Smith}    |36636|M     |3100  |
# |{Michael, Rose, }   |40288|M     |4300  |
# |{Robert, , Williams}|42114|M     |1400  |
# |{Maria, Anne, Jones}|39192|F     |5500  |
# |{Jen, Mary, Brown}  |     |F     |-1    |
# +--------------------+-----+------+------+

# %%
from pyspark.sql.functions import col,struct,when
updatedDF = df2.withColumn("OtherInfo", 
    struct(col("id").alias("identifier"),
    col("gender").alias("gender"),
    col("salary").alias("salary"),
    when(col("salary").cast(IntegerType()) < 2000,"Low")
      .when(col("salary").cast(IntegerType()) < 4000,"Medium")
      .otherwise("High").alias("Salary_Grade")
  )).drop("id","gender","salary")

updatedDF.printSchema()
updatedDF.show(truncate=False)
# Out:
# root
#  |-- name: struct (nullable = true)
#  |    |-- firstname: string (nullable = true)
#  |    |-- middlename: string (nullable = true)
#  |    |-- lastname: string (nullable = true)
#  |-- OtherInfo: struct (nullable = false)
#  |    |-- identifier: string (nullable = true)
#  |    |-- gender: string (nullable = true)
#  |    |-- salary: integer (nullable = true)
#  |    |-- Salary_Grade: string (nullable = false)
#
# +--------------------+------------------------+
# |name                |OtherInfo               |
# +--------------------+------------------------+
# |{James, , Smith}    |{36636, M, 3100, Medium}|
# |{Michael, Rose, }   |{40288, M, 4300, High}  |
# |{Robert, , Williams}|{42114, M, 1400, Low}   |
# |{Maria, Anne, Jones}|{39192, F, 5500, High}  |
# |{Jen, Mary, Brown}  |{, F, -1, Low}          |
# +--------------------+------------------------+
